# %%
import pandas as pd
import quandl
import numpy as np
import math
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression

# %%
df = quandl.get('WIKI/GOOGL')
df
# Out:
#                Open     High      Low     Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19   100.01   104.06    95.96   100.335  44659000.0          0.0
# 2004-08-20   101.01   109.08   100.50   108.310  22834300.0          0.0
# 2004-08-23   110.76   113.48   109.05   109.400  18256100.0          0.0
# 2004-08-24   111.24   111.60   103.57   104.870  15247300.0          0.0
# 2004-08-25   104.76   108.00   103.88   106.000   9188600.0          0.0
# ...             ...      ...      ...       ...         ...          ...
# 2018-03-21  1092.57  1108.70  1087.21  1094.000   1990515.0          0.0
# 2018-03-22  1080.01  1083.92  1049.64  1053.150   3418154.0          0.0
# 2018-03-23  1051.37  1066.78  1024.87  1026.550   2413517.0          0.0
# 2018-03-26  1050.60  1059.27  1010.58  1054.090   3272409.0          0.0
# 2018-03-27  1063.90  1064.54   997.62  1006.940   2940957.0          0.0
#
#             Split Ratio    Adj. Open    Adj. High     Adj. Low   Adj. Close  \
# Date
# 2004-08-19          1.0    50.159839    52.191109    48.128568    50.322842
# 2004-08-20          1.0    50.661387    54.708881    50.405597    54.322689
# 2004-08-23          1.0    55.551482    56.915693    54.693835    54.869377
# 2004-08-24          1.0    55.792225    55.972783    51.945350    52.597363
# 2004-08-25          1.0    52.542193    54.167209    52.100830    53.164113
# ...                 ...          ...          ...          ...          ...
# 2018-03-21          1.0  1092.570000  1108.700000  1087.210000  1094.000000
# 2018-03-22          1.0  1080.010000  1083.920000  1049.640000  1053.150000
# 2018-03-23          1.0  1051.370000  1066.780000  1024.870000  1026.550000
# 2018-03-26          1.0  1050.600000  1059.270000  1010.580000  1054.090000
# 2018-03-27          1.0  1063.900000  1064.540000   997.620000  1006.940000
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# 2004-08-24   15247300.0
# 2004-08-25    9188600.0
# ...                 ...
# 2018-03-21    1990515.0
# 2018-03-22    3418154.0
# 2018-03-23    2413517.0
# 2018-03-26    3272409.0
# 2018-03-27    2940957.0
#
# [3424 rows x 12 columns]

# %%
df = df[['Adj. Open','Adj. High','Adj. Low','Adj. Close','Adj. Volume']]
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Close']) / df['Adj. Close'] * 100.0
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0

df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]

print(df.head())
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume
# Date
# 2004-08-19   50.322842  3.712563    0.324968   44659000.0
# 2004-08-20   54.322689  0.710922    7.227007   22834300.0
# 2004-08-23   54.869377  3.729433   -1.227880   18256100.0
# 2004-08-24   52.597363  6.417469   -5.726357   15247300.0
# 2004-08-25   53.164113  1.886792    1.183658    9188600.0
# /var/folders/r_/j3w1_1417lv6xrnc1tq63rsr0000gn/T/ipykernel_18995/3174436356.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HL_PCT'] = (df['Adj. High'] - df['Adj. Close']) / df['Adj. Close'] * 100.0
# /var/folders/r_/j3w1_1417lv6xrnc1tq63rsr0000gn/T/ipykernel_18995/3174436356.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0

# %%
forecast_col = 'Adj. Close' # Forecast is output
df.fillna(-99999, inplace=True)

forecast_out = int(math.ceil(0.01 * len(df))) #can change depending on what we want

df['label'] = df[forecast_col].shift(-forecast_out)
df.dropna(inplace=True)
print(df.head())
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume      label
# Date
# 2004-08-19   50.322842  3.712563    0.324968   44659000.0  67.739104
# 2004-08-20   54.322689  0.710922    7.227007   22834300.0  69.399229
# 2004-08-23   54.869377  3.729433   -1.227880   18256100.0  68.752232
# 2004-08-24   52.597363  6.417469   -5.726357   15247300.0  69.639972
# 2004-08-25   53.164113  1.886792    1.183658    9188600.0  69.078238

# %%
X = np.array(df.drop(['label'], axis=1, inplace=True))
y = np.array(df['label'])

X = preprocessing.scale(X)

X = X[:-forecast_out+1]
df.dropna(inplace=True)
y = np.array(df['label'])

print(len(X), len(y))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 X = np.array(df.drop(['label'], axis=1, inplace=True))
#       2 y = np.array(df['label'])
#       4 X = preprocessing.scale(X)
#
# File ~/Documents/GitHub/Jupyter_ML_Practise/.venv/lib/python3.11/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/Documents/GitHub/Jupyter_ML_Practise/.venv/lib/python3.11/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/Documents/GitHub/Jupyter_ML_Practise/.venv/lib/python3.11/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/Documents/GitHub/Jupyter_ML_Practise/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['label'] not found in axis"
